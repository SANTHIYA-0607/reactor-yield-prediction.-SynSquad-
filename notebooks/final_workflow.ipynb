# %% [markdown]
# # Final Reactor Yield Workflow
# This notebook documents the shortlisted submission workflow. The final model is ExtraTreesRegressor with Feature Set B.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from final_extratrees_model import main

# %%
main()
